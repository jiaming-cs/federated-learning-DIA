# %%
import loader
import torch
from torch import nn
from torch.utils.data import DataLoader
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
import sklearn.metrics
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier
import pickle
import numpy as np

import datetime

# Running time calculate: start time
start_time = datetime.datetime.now()

# Hyper Parameters
EPOCH = 1
BATCH_SIZE = 128
TIME_STEP = 100  # length of LSTM time sequence, or window size
INPUT_SIZE = 6 # num of feature for deep learning
LR = 0.001   # learning rate
KFOLD = 1
isGPU = torch.cuda.is_available()

# detection deep learning dataset path
data_path_DL = './PELS_dataset/w100_final_dataset/fault_detection/deep_learning/'
all_data_DL = loader.waveformDetectionDL(data_path_DL)

# diagnosis deep learning datasset path
#data_path_DL = '../new_clean_data/w100_final_dataset/fault_diagnosis/deep_learning/'
#all_data_DL = loader.waveformDiagnosisDL(data_path_DL)

# %%
class LSTM(nn.Module):
    def __init__(self):
        super(LSTM, self).__init__()
        
        self.lstm = nn.LSTM(
                input_size=INPUT_SIZE,
                hidden_size=32,
                num_layers=5,
                batch_first=True,
                )
        #fully connected
        #self.out = nn.Linear(32, 9)
        self.out = nn.Linear(32, 2)
    
    def forward(self, x):
        lstm_out, (h_n, h_c) = self.lstm(x, None)
        out = self.out(lstm_out[:, -1, :])
        return out

# %%
data_output = {'lstm':{'F1':[], 'precision':[], 'recall':[], 'accuracy':[], 'auc':[], 'fpr':[], 'tpr':[], 'test_loss':[], 'train_loss':[]}}

for num_of_training in range(KFOLD):
    print('------------------fold {}------------------------'.format(num_of_training + 1))
    lstm = LSTM()
    
    if isGPU:
        lstm = nn.DataParallel(lstm, device_ids=[0,1,2,3])
        lstm.cuda()

    lstm_optimizer = torch.optim.Adam(lstm.parameters(), lr=LR)
    loss_func = nn.CrossEntropyLoss()
    
    # print the structure of the network
    print(lstm)
    
    # data partition: 15% testing, 85% training
    training_data, test_data = torch.utils.data.random_split(all_data_DL, [int(all_data_DL.len * 0.85), all_data_DL.len - int(all_data_DL.len * 0.85)])
    training_Loader = DataLoader(dataset=training_data, batch_size=BATCH_SIZE, shuffle=True)
    test_Loader = DataLoader(dataset=test_data, batch_size=BATCH_SIZE)
    
    # training and testing
    lstm_test_loss_draw = []
    
    lstm_loss_draw = []
    
    for epoch in range(EPOCH):
        print('-----------------------epoch {}----------------------'.format(epoch + 1))
        
        # training-----------------------------------------
        lstm_train_loss = 0.
        
        lstm_train_acc = 0.
        
        lstm.train()
        
        for step, (batch_x, batch_y) in enumerate(training_Loader):
            batch_x = batch_x.view(-1, TIME_STEP, INPUT_SIZE)
            
            if isGPU:
                batch_x = batch_x.cuda()
                batch_y = batch_y.cuda()

            output_lstm = lstm(batch_x)
            batch_y = batch_y.type(torch.LongTensor)
            loss_lstm = loss_func(output_lstm, batch_y)
            
            lstm_train_loss += loss_lstm.item()
            
            
            
            if isGPU:
                lstm_pred = torch.max(output_lstm, 1)[1].cuda()
            else:
                lstm_pred = torch.max(output_lstm, 1)[1]
            
            lstm_train_correct = (lstm_pred == batch_y).sum()
            
            lstm_train_acc += lstm_train_correct.item()
            
            lstm_optimizer.zero_grad()
            
            loss_lstm.backward()
            
            lstm_optimizer.step()
            
            print('Epoch:{} Step:{}/{} LSTM:\n Train Loss: {:.6f}, Accuracy: {:.6f}\n'.format(epoch, step+1, len(training_Loader), lstm_train_loss / 
                (len(training_data)), lstm_train_acc / (len(training_data))))
        
        lstm_loss_draw.append(lstm_train_loss/(len(training_data)))
        
        
        # evaluation--------------------------------------------------
        lstm.eval()
        
        lstm_eval_loss = 0.
        
        lstm_eval_acc = 0.
        
        lstm_final_prediction = np.array([])
        lstm_final_test = np.array([])
        lstm_f1_score = []
        lstm_recall = []
        lstm_precision = []
        lstm_accuracy = []
      
        for step, (batch_x, batch_y) in enumerate(test_Loader):
            batch_x = batch_x.view(-1, TIME_STEP, INPUT_SIZE)
            
            if isGPU:
                batch_x = batch_x.cuda()
                batch_y = batch_y.cuda()
    
            output_lstm = lstm(batch_x)
            batch_y = batch_y.type(torch.LongTensor)
            loss_lstm = loss_func(output_lstm, batch_y)
            
            lstm_eval_loss += loss_lstm.item()
            
            lstm_pred = torch.max(output_lstm, 1)[1]
            
            lstm_eval_correct = (lstm_pred == batch_y).sum()
            
            
            if isGPU:
                lstm_pred = torch.max(output_lstm, 1)[1].cuda()
            else:
                lstm_pred = torch.max(output_lstm, 1)[1]
            
            lstm_eval_acc += lstm_eval_correct.item()
                      
            # F1 metrics
            lstm_final_prediction = np.concatenate((lstm_final_prediction, lstm_pred.cpu().numpy()), axis=0)
            lstm_final_test = np.concatenate((lstm_final_test, batch_y), axis=0)
        
        lstm_f1_score.append(sklearn.metrics.f1_score(lstm_final_test, lstm_final_prediction, average='binary').item())
        lstm_recall.append(sklearn.metrics.recall_score(lstm_final_test, lstm_final_prediction, average='binary').item())
        lstm_precision.append(sklearn.metrics.precision_score(lstm_final_test, lstm_final_prediction, average='binary').item())
        lstm_accuracy.append(lstm_eval_acc / (len(test_data)))

        
        print('LSTM:\n Test Loss: {:.6f}, Accuracy: {:.6f}'.format(lstm_eval_loss / (len(test_data)), lstm_eval_acc / (len(test_data))))
        
        lstm_test_loss_draw.append(lstm_eval_loss/(len(test_data)))
        
        print('LSTM:\n F1: {}, recall: {}, precision: {}'.format(lstm_f1_score[-1], lstm_recall[-1], lstm_precision[-1]))
        
    # ROC curve and AUC
    #lstm_test_y = label_binarize(lstm_final_test, classes=[0, 1, 2, 3, 4, 5, 6, 7, 8])
    #lstm_pred_y = label_binarize(lstm_final_prediction, classes=[0, 1, 2, 3, 4, 5, 6, 7, 8])
    lstm_test_y = label_binarize(lstm_final_test, classes=[0, 1])
    lstm_pred_y = label_binarize(lstm_final_prediction, classes=[0, 1])
    
    lstm_fpr, lstm_tpr, _ = roc_curve(lstm_test_y.ravel(), lstm_pred_y.ravel())
    lstm_roc_auc = auc(lstm_fpr, lstm_tpr)
    
    
    data_output['lstm']['F1'].append(lstm_f1_score[-1])
    data_output['lstm']['precision'].append(lstm_precision[-1])
    data_output['lstm']['recall'].append(lstm_recall[-1])
    data_output['lstm']['accuracy'].append(lstm_accuracy[-1])
    data_output['lstm']['auc'].append(lstm_roc_auc.item())
    data_output['lstm']['fpr'].append(list(lstm_fpr))
    data_output['lstm']['tpr'].append(list(lstm_tpr))
    data_output['lstm']['test_loss'].append(lstm_test_loss_draw)
    data_output['lstm']['train_loss'].append(lstm_loss_draw)
# Out:
# /549 LSTM:
#  Train Loss: 0.002111, Accuracy: 0.352041
#
# Epoch:0 Step:267/549 LSTM:
#  Train Loss: 0.002118, Accuracy: 0.353450
#
# Epoch:0 Step:268/549 LSTM:
#  Train Loss: 0.002125, Accuracy: 0.354874
#
# Epoch:0 Step:269/549 LSTM:
#  Train Loss: 0.002132, Accuracy: 0.356369
#
# Epoch:0 Step:270/549 LSTM:
#  Train Loss: 0.002138, Accuracy: 0.357793
#
# Epoch:0 Step:271/549 LSTM:
#  Train Loss: 0.002145, Accuracy: 0.359259
#
# Epoch:0 Step:272/549 LSTM:
#  Train Loss: 0.002152, Accuracy: 0.360697
#
# Epoch:0 Step:273/549 LSTM:
#  Train Loss: 0.002159, Accuracy: 0.362135
#
# Epoch:0 Step:274/549 LSTM:
#  Train Loss: 0.002165, Accuracy: 0.363601
#
# Epoch:0 Step:275/549 LSTM:
#  Train Loss: 0.002173, Accuracy: 0.365011
#
# Epoch:0 Step:276/549 LSTM:
#  Train Loss: 0.002180, Accuracy: 0.366406
#
# Epoch:0 Step:277/549 LSTM:
#  Train Loss: 0.002187, Accuracy: 0.367858
#
# Epoch:0 Step:278/549 LSTM:
#  Train Loss: 0.002194, Accuracy: 0.369282
#
# Epoch:0 Step:279/549 LSTM:
#  Train Loss: 0.002200, Accuracy: 0.370777
#
# Epoch:0 Step:280/549 LSTM:
#  Train Loss: 0.002207, Accuracy: 0.372201
#
# Epoch:0 Step:281/549 LSTM:
#  Train Loss: 0.002214, Accuracy: 0.373567
#
# Epoch:0 Step:282/549 LSTM:
#  Train Loss: 0.002222, Accuracy: 0.374877
#
# Epoch:0 Step:283/549 LSTM:
#  Train Loss: 0.002230, Accuracy: 0.376230
#
# Epoch:0 Step:284/549 LSTM:
#  Train Loss: 0.002236, Accuracy: 0.377682
#
# Epoch:0 Step:285/549 LSTM:
#  Train Loss: 0.002243, Accuracy: 0.379091
#
# Epoch:0 Step:286/549 LSTM:
#  Train Loss: 0.002250, Accuracy: 0.380444
#
# Epoch:0 Step:287/549 LSTM:
#  Train Loss: 0.002257, Accuracy: 0.381967
#
# Epoch:0 Step:288/549 LSTM:
#  Train Loss: 0.002264, Accuracy: 0.383377
#
# Epoch:0 Step:289/549 LSTM:
#  Train Loss: 0.002272, Accuracy: 0.384701
#
# Epoch:0 Step:290/549 LSTM:
#  Train Loss: 0.002279, Accuracy: 0.386082
#
# Epoch:0 Step:291/549 LSTM:
#  Train Loss: 0.002287, Accuracy: 0.387434
#
# Epoch:0 Step:292/549 LSTM:
#  Train Loss: 0.002293, Accuracy: 0.388887
#
# Epoch:0 Step:293/549 LSTM:
#  Train Loss: 0.002300, Accuracy: 0.390282
#
# Epoch:0 Step:294/549 LSTM:
#  Train Loss: 0.002308, Accuracy: 0.391606
#
# Epoch:0 Step:295/549 LSTM:
#  Train Loss: 0.002315, Accuracy: 0.392987
#
# Epoch:0 Step:296/549 LSTM:
#  Train Loss: 0.002322, Accuracy: 0.394439
#
# Epoch:0 Step:297/549 LSTM:
#  Train Loss: 0.002330, Accuracy: 0.395806
#
# Epoch:0 Step:298/549 LSTM:
#  Train Loss: 0.002337, Accuracy: 0.397144
#
# Epoch:0 Step:299/549 LSTM:
#  Train Loss: 0.002344, Accuracy: 0.398568
#
# Epoch:0 Step:300/549 LSTM:
#  Train Loss: 0.002351, Accuracy: 0.400077
#
# Epoch:0 Step:301/549 LSTM:
#  Train Loss: 0.002359, Accuracy: 0.401330
#
# Epoch:0 Step:302/549 LSTM:
#  Train Loss: 0.002365, Accuracy: 0.402825
#
# Epoch:0 Step:303/549 LSTM:
#  Train Loss: 0.002372, Accuracy: 0.404234
#
# Epoch:0 Step:304/549 LSTM:
#  Train Loss: 0.002378, Accuracy: 0.405629
#
# Epoch:0 Step:305/549 LSTM:
#  Train Loss: 0.002385, Accuracy: 0.407039
#
# Epoch:0 Step:306/549 LSTM:
#  Train Loss: 0.002392, Accuracy: 0.408534
#
# Epoch:0 Step:307/549 LSTM:
#  Train Loss: 0.002399, Accuracy: 0.410000
#
# Epoch:0 Step:308/549 LSTM:
#  Train Loss: 0.002404, Accuracy: 0.411509
#
# Epoch:0 Step:309/549 LSTM:
#  Train Loss: 0.002412, Accuracy: 0.412876
#
# Epoch:0 Step:310/549 LSTM:
#  Train Loss: 0.002418, Accuracy: 0.414314
#
# Epoch:0 Step:311/549 LSTM:
#  Train Loss: 0.002424, Accuracy: 0.415795
#
# Epoch:0 Step:312/549 LSTM:
#  Train Loss: 0.002432, Accuracy: 0.417275
#
# Epoch:0 Step:313/549 LSTM:
#  Train Loss: 0.002438, Accuracy: 0.418742
#
# Epoch:0 Step:314/549 LSTM:
#  Train Loss: 0.002445, Accuracy: 0.420151
#
# Epoch:0 Step:315/549 LSTM:
#  Train Loss: 0.002454, Accuracy: 0.421433
#
# Epoch:0 Step:316/549 LSTM:
#  Train Loss: 0.002461, Accuracy: 0.422842
#
# Epoch:0 Step:317/549 LSTM:
#  Train Loss: 0.002468, Accuracy: 0.424266
#
# Epoch:0 Step:318/549 LSTM:
#  Train Loss: 0.002474, Accuracy: 0.425732
#
# Epoch:0 Step:319/549 LSTM:
#  Train Loss: 0.002481, Accuracy: 0.427156
#
# Epoch:0 Step:320/549 LSTM:
#  Train Loss: 0.002488, Accuracy: 0.428594
#
# Epoch:0 Step:321/549 LSTM:
#  Train Loss: 0.002495, Accuracy: 0.430046
#
# Epoch:0 Step:322/549 LSTM:
#  Train Loss: 0.002502, Accuracy: 0.431527
#
# Epoch:0 Step:323/549 LSTM:
#  Train Loss: 0.002509, Accuracy: 0.432851
#
# Epoch:0 Step:324/549 LSTM:
#  Train Loss: 0.002516, Accuracy: 0.434346
#
# Epoch:0 Step:325/549 LSTM:
#  Train Loss: 0.002523, Accuracy: 0.435826
#
# Epoch:0 Step:326/549 LSTM:
#  Train Loss: 0.002531, Accuracy: 0.437179
#
# Epoch:0 Step:327/549 LSTM:
#  Train Loss: 0.002538, Accuracy: 0.438517
#
# Epoch:0 Step:328/549 LSTM:
#  Train Loss: 0.002545, Accuracy: 0.439912
#
# Epoch:0 Step:329/549 LSTM:
#  Train Loss: 0.002552, Accuracy: 0.441336
#
# Epoch:0 Step:330/549 LSTM:
#  Train Loss: 0.002560, Accuracy: 0.442674
#
# Epoch:0 Step:331/549 LSTM:
#  Train Loss: 0.002567, Accuracy: 0.444084
#
# Epoch:0 Step:332/549 LSTM:
#  Train Loss: 0.002574, Accuracy: 0.445507
#
# Epoch:0 Step:333/549 LSTM:
#  Train Loss: 0.002582, Accuracy: 0.446803
#
# Epoch:0 Step:334/549 LSTM:
#  Train Loss: 0.002589, Accuracy: 0.448127
#
# Epoch:0 Step:335/549 LSTM:
#  Train Loss: 0.002596, Accuracy: 0.449594
#
# Epoch:0 Step:336/549 LSTM:
#  Train Loss: 0.002603, Accuracy: 0.450946
#
# Epoch:0 Step:337/549 LSTM:
#  Train Loss: 0.002611, Accuracy: 0.452313
#
# Epoch:0 Step:338/549 LSTM:
#  Train Loss: 0.002618, Accuracy: 0.453694
#
# Epoch:0 Step:339/549 LSTM:
#  Train Loss: 0.002625, Accuracy: 0.455132
#
# Epoch:0 Step:340/549 LSTM:
#  Train Loss: 0.002632, Accuracy: 0.456612
#
# Epoch:0 Step:341/549 LSTM:
#  Train Loss: 0.002639, Accuracy: 0.457951
#
# Epoch:0 Step:342/549 LSTM:
#  Train Loss: 0.002646, Accuracy: 0.459389
#
# Epoch:0 Step:343/549 LSTM:
#  Train Loss: 0.002654, Accuracy: 0.460727
#
# Epoch:0 Step:344/549 LSTM:
#  Train Loss: 0.002660, Accuracy: 0.462136
#
# Epoch:0 Step:345/549 LSTM:
#  Train Loss: 0.002668, Accuracy: 0.463589
#
# Epoch:0 Step:346/549 LSTM:
#  Train Loss: 0.002675, Accuracy: 0.464913
#
# Epoch:0 Step:347/549 LSTM:
#  Train Loss: 0.002682, Accuracy: 0.466308
#
# Epoch:0 Step:348/549 LSTM:
#  Train Loss: 0.002689, Accuracy: 0.467732
#
# Epoch:0 Step:349/549 LSTM:
#  Train Loss: 0.002695, Accuracy: 0.469212
#
# Epoch:0 Step:350/549 LSTM:
#  Train Loss: 0.002703, Accuracy: 0.470593
#
# Epoch:0 Step:351/549 LSTM:
#  Train Loss: 0.002710, Accuracy: 0.471974
#
# Epoch:0 Step:352/549 LSTM:
#  Train Loss: 0.002716, Accuracy: 0.473426
#
# Epoch:0 Step:353/549 LSTM:
#  Train Loss: 0.002722, Accuracy: 0.474864
#
# Epoch:0 Step:354/549 LSTM:
#  Train Loss: 0.002730, Accuracy: 0.476245
#
# Epoch:0 Step:355/549 LSTM:
#  Train Loss: 0.002737, Accuracy: 0.477626
#
# Epoch:0 Step:356/549 LSTM:
#  Train Loss: 0.002744, Accuracy: 0.479007
#
# Epoch:0 Step:357/549 LSTM:
#  Train Loss: 0.002751, Accuracy: 0.480460
#
# Epoch:0 Step:358/549 LSTM:
#  Train Loss: 0.002759, Accuracy: 0.481741
#
# Epoch:0 Step:359/549 LSTM:
#  Train Loss: 0.002766, Accuracy: 0.483136
#
# Epoch:0 Step:360/549 LSTM:
#  Train Loss: 0.002773, Accuracy: 0.484546
#
# Epoch:0 Step:361/549 LSTM:
#  Train Loss: 0.002781, Accuracy: 0.485941
#
# Epoch:0 Step:362/549 LSTM:
#  Train Loss: 0.002788, Accuracy: 0.487293
#
# Epoch:0 Step:363/549 LSTM:
#  Train Loss: 0.002796, Accuracy: 0.488660
#
# Epoch:0 Step:364/549 LSTM:
#  Train Loss: 0.002805, Accuracy: 0.489913
#
# Epoch:0 Step:365/549 LSTM:
#  Train Loss: 0.002812, Accuracy: 0.491351
#
# Epoch:0 Step:366/549 LSTM:
#  Train Loss: 0.002819, Accuracy: 0.492760
#
# Epoch:0 Step:367/549 LSTM:
#  Train Loss: 0.002827, Accuracy: 0.494113
#
# Epoch:0 Step:368/549 LSTM:
#  Train Loss: 0.002833, Accuracy: 0.495579
#
# Epoch:0 Step:369/549 LSTM:
#  Train Loss: 0.002840, Accuracy: 0.496975
#
# Epoch:0 Step:370/549 LSTM:
#  Train Loss: 0.002847, Accuracy: 0.498441
#
# Epoch:0 Step:371/549 LSTM:
#  Train Loss: 0.002855, Accuracy: 0.499779
#
# Epoch:0 Step:372/549 LSTM:
#  Train Loss: 0.002861, Accuracy: 0.501203
#
# Epoch:0 Step:373/549 LSTM:
#  Train Loss: 0.002869, Accuracy: 0.502541
#
# Epoch:0 Step:374/549 LSTM:
#  Train Loss: 0.002876, Accuracy: 0.503979
#
# Epoch:0 Step:375/549 LSTM:
#  Train Loss: 0.002883, Accuracy: 0.505460
#
# Epoch:0 Step:376/549 LSTM:
#  Train Loss: 0.002890, Accuracy: 0.506841
#
# Epoch:0 Step:377/549 LSTM:
#  Train Loss: 0.002898, Accuracy: 0.508122
#
# Epoch:0 Step:378/549 LSTM:
#  Train Loss: 0.002905, Accuracy: 0.509489
#
# Epoch:0 Step:379/549 LSTM:
#  Train Loss: 0.002912, Accuracy: 0.510842
#
# Epoch:0 Step:380/549 LSTM:
#  Train Loss: 0.002919, Accuracy: 0.512280
#
# Epoch:0 Step:381/549 LSTM:
#  Train Loss: 0.002926, Accuracy: 0.513604
#
# Epoch:0 Step:382/549 LSTM:
#  Train Loss: 0.002934, Accuracy: 0.514899
#
# Epoch:0 Step:383/549 LSTM:
#  Train Loss: 0.002940, Accuracy: 0.516394
#
# Epoch:0 Step:384/549 LSTM:
#  Train Loss: 0.002947, Accuracy: 0.517761
#
# Epoch:0 Step:385/549 LSTM:
#  Train Loss: 0.002955, Accuracy: 0.519042
#
# Epoch:0 Step:386/549 LSTM:
#  Train Loss: 0.002963, Accuracy: 0.520466
#
# Epoch:0 Step:387/549 LSTM:
#  Train Loss: 0.002970, Accuracy: 0.521918
#
# Epoch:0 Step:388/549 LSTM:
#  Train Loss: 0.002976, Accuracy: 0.523370
#
# Epoch:0 Step:389/549 LSTM:
#  Train Loss: 0.002984, Accuracy: 0.524765
#
# Epoch:0 Step:390/549 LSTM:
#  Train Loss: 0.002990, Accuracy: 0.526189
#
# Epoch:0 Step:391/549 LSTM:
#  Train Loss: 0.002999, Accuracy: 0.527485
#
# Epoch:0 Step:392/549 LSTM:
#  Train Loss: 0.003006, Accuracy: 0.528894
#
# Epoch:0 Step:393/549 LSTM:
#  Train Loss: 0.003012, Accuracy: 0.530318
#
# Epoch:0 Step:394/549 LSTM:
#  Train Loss: 0.003020, Accuracy: 0.531727
#
# Epoch:0 Step:395/549 LSTM:
#  Train Loss: 0.003027, Accuracy: 0.533151
#
# Epoch:0 Step:396/549 LSTM:
#  Train Loss: 0.003034, Accuracy: 0.534504
#
# Epoch:0 Step:397/549 LSTM:
#  Train Loss: 0.003041, Accuracy: 0.535956
#
# Epoch:0 Step:398/549 LSTM:
#  Train Loss: 0.003048, Accuracy: 0.537280
#
# Epoch:0 Step:399/549 LSTM:
#  Train Loss: 0.003055, Accuracy: 0.538704
#
# Epoch:0 Step:400/549 LSTM:
#  Train Loss: 0.003062, Accuracy: 0.540070
#
# Epoch:0 Step:401/549 LSTM:
#  Train Loss: 0.003069, Accuracy: 0.541451
#
# Epoch:0 Step:402/549 LSTM:
#  Train Loss: 0.003076, Accuracy: 0.542904
#
# Epoch:0 Step:403/549 LSTM:
#  Train Loss: 0.003083, Accuracy: 0.544341
#
# Epoch:0 Step:404/549 LSTM:
#  Train Loss: 0.003090, Accuracy: 0.545708
#
# Epoch:0 Step:405/549 LSTM:
#  Train Loss: 0.003097, Accuracy: 0.547246
#
# Epoch:0 Step:406/549 LSTM:
#  Train Loss: 0.003103, Accuracy: 0.548726
#
# Epoch:0 Step:407/549 LSTM:
#  Train Loss: 0.003110, Accuracy: 0.550093
#
# Epoch:0 Step:408/549 LSTM:
#  Train Loss: 0.003118, Accuracy: 0.551446
#
# Epoch:0 Step:409/549 LSTM:
#  Train Loss: 0.003125, Accuracy: 0.552855
#
# Epoch:0 Step:410/549 LSTM:
#  Train Loss: 0.003132, Accuracy: 0.554364
#
# Epoch:0 Step:411/549 LSTM:
#  Train Loss: 0.003138, Accuracy: 0.555845
#
# Epoch:0 Step:412/549 LSTM:
#  Train Loss: 0.003145, Accuracy: 0.557340
#
# Epoch:0 Step:413/549 LSTM:
#  Train Loss: 0.003150, Accuracy: 0.558878
#
# Epoch:0 Step:414/549 LSTM:
#  Train Loss: 0.003157, Accuracy: 0.560358
#
# Epoch:0 Step:415/549 LSTM:
#  Train Loss: 0.003164, Accuracy: 0.561753
#
# Epoch:0 Step:416/549 LSTM:
#  Train Loss: 0.003170, Accuracy: 0.563177
#
# Epoch:0 Step:417/549 LSTM:
#  Train Loss: 0.003178, Accuracy: 0.564572
#
# Epoch:0 Step:418/549 LSTM:
#  Train Loss: 0.003185, Accuracy: 0.565911
#
# Epoch:0 Step:419/549 LSTM:
#  Train Loss: 0.003191, Accuracy: 0.567434
#
# Epoch:0 Step:420/549 LSTM:
#  Train Loss: 0.003199, Accuracy: 0.568701
#
# Epoch:0 Step:421/549 LSTM:
#  Train Loss: 0.003207, Accuracy: 0.569954
#
# Epoch:0 Step:422/549 LSTM:
#  Train Loss: 0.003216, Accuracy: 0.571235
#
# Epoch:0 Step:423/549 LSTM:
#  Train Loss: 0.003223, Accuracy: 0.572673
#
# Epoch:0 Step:424/549 LSTM:
#  Train Loss: 0.003230, Accuracy: 0.574069
#
# Epoch:0 Step:425/549 LSTM:
#  Train Loss: 0.003237, Accuracy: 0.575521
#
# Epoch:0 Step:426/549 LSTM:
#  Train Loss: 0.003244, Accuracy: 0.576887
#
# Epoch:0 Step:427/549 LSTM:
#  Train Loss: 0.003250, Accuracy: 0.578325
#
# Epoch:0 Step:428/549 LSTM:
#  Train Loss: 0.003258, Accuracy: 0.579664
#
# Epoch:0 Step:429/549 LSTM:
#  Train Loss: 0.003265, Accuracy: 0.581073
#
# Epoch:0 Step:430/549 LSTM:
#  Train Loss: 0.003272, Accuracy: 0.582383
#
# Epoch:0 Step:431/549 LSTM:
#  Train Loss: 0.003280, Accuracy: 0.583736
#
# Epoch:0 Step:432/549 LSTM:
#  Train Loss: 0.003287, Accuracy: 0.585074
#
# Epoch:0 Step:433/549 LSTM:
#  Train Loss: 0.003294, Accuracy: 0.586526
#
# Epoch:0 Step:434/549 LSTM:
#  Train Loss: 0.003300, Accuracy: 0.587964
#
# Epoch:0 Step:435/549 LSTM:
#  Train Loss: 0.003307, Accuracy: 0.589445
#
# Epoch:0 Step:436/549 LSTM:
#  Train Loss: 0.003313, Accuracy: 0.590954
#
# Epoch:0 Step:437/549 LSTM:
#  Train Loss: 0.003319, Accuracy: 0.592449
#
# Epoch:0 Step:438/549 LSTM:
#  Train Loss: 0.003326, Accuracy: 0.593915
#
# Epoch:0 Step:439/549 LSTM:
#  Train Loss: 0.003333, Accuracy: 0.595367
#
# Epoch:0 Step:440/549 LSTM:
#  Train Loss: 0.003341, Accuracy: 0.596634
#
# Epoch:0 Step:441/549 LSTM:
#  Train Loss: 0.003349, Accuracy: 0.597973
#
# Epoch:0 Step:442/549 LSTM:
#  Train Loss: 0.003356, Accuracy: 0.599339
#
# Epoch:0 Step:443/549 LSTM:
#  Train Loss: 0.003364, Accuracy: 0.600706
#
# Epoch:0 Step:444/549 LSTM:
#  Train Loss: 0.003370, Accuracy: 0.602187
#
# Epoch:0 Step:445/549 LSTM:
#  Train Loss: 0.003377, Accuracy: 0.603625
#
# Epoch:0 Step:446/549 LSTM:
#  Train Loss: 0.003382, Accuracy: 0.605120
#
# Epoch:0 Step:447/549 LSTM:
#  Train Loss: 0.003388, Accuracy: 0.606572
#
# Epoch:0 Step:448/549 LSTM:
#  Train Loss: 0.003396, Accuracy: 0.607967
#
# Epoch:0 Step:449/549 LSTM:
#  Train Loss: 0.003403, Accuracy: 0.609362
#
# Epoch:0 Step:450/549 LSTM:
#  Train Loss: 0.003410, Accuracy: 0.610815
#
# Epoch:0 Step:451/549 LSTM:
#  Train Loss: 0.003417, Accuracy: 0.612210
#
# Epoch:0 Step:452/549 LSTM:
#  Train Loss: 0.003423, Accuracy: 0.613733
#
# Epoch:0 Step:453/549 LSTM:
#  Train Loss: 0.003430, Accuracy: 0.615185
#
# Epoch:0 Step:454/549 LSTM:
#  Train Loss: 0.003436, Accuracy: 0.616652
#
# Epoch:0 Step:455/549 LSTM:
#  Train Loss: 0.003443, Accuracy: 0.618061
#
# Epoch:0 Step:456/549 LSTM:
#  Train Loss: 0.003450, Accuracy: 0.619428
#
# Epoch:0 Step:457/549 LSTM:
#  Train Loss: 0.003457, Accuracy: 0.620795
#
# Epoch:0 Step:458/549 LSTM:
#  Train Loss: 0.003464, Accuracy: 0.622247
#
# Epoch:0 Step:459/549 LSTM:
#  Train Loss: 0.003471, Accuracy: 0.623685
#
# Epoch:0 Step:460/549 LSTM:
#  Train Loss: 0.003477, Accuracy: 0.625194
#
# Epoch:0 Step:461/549 LSTM:
#  Train Loss: 0.003483, Accuracy: 0.626717
#
# Epoch:0 Step:462/549 LSTM:
#  Train Loss: 0.003490, Accuracy: 0.628141
#
# Epoch:0 Step:463/549 LSTM:
#  Train Loss: 0.003497, Accuracy: 0.629536
#
# Epoch:0 Step:464/549 LSTM:
#  Train Loss: 0.003505, Accuracy: 0.630832
#
# Epoch:0 Step:465/549 LSTM:
#  Train Loss: 0.003512, Accuracy: 0.632142
#
# Epoch:0 Step:466/549 LSTM:
#  Train Loss: 0.003519, Accuracy: 0.633508
#
# Epoch:0 Step:467/549 LSTM:
#  Train Loss: 0.003526, Accuracy: 0.634946
#
# Epoch:0 Step:468/549 LSTM:
#  Train Loss: 0.003534, Accuracy: 0.636213
#
# Epoch:0 Step:469/549 LSTM:
#  Train Loss: 0.003541, Accuracy: 0.637594
#
# Epoch:0 Step:470/549 LSTM:
#  Train Loss: 0.003548, Accuracy: 0.638947
#
# Epoch:0 Step:471/549 LSTM:
#  Train Loss: 0.003555, Accuracy: 0.640342
#
# Epoch:0 Step:472/549 LSTM:
#  Train Loss: 0.003562, Accuracy: 0.641681
#
# Epoch:0 Step:473/549 LSTM:
#  Train Loss: 0.003569, Accuracy: 0.642990
#
# Epoch:0 Step:474/549 LSTM:
#  Train Loss: 0.003577, Accuracy: 0.644343
#
# Epoch:0 Step:475/549 LSTM:
#  Train Loss: 0.003584, Accuracy: 0.645767
#
# Epoch:0 Step:476/549 LSTM:
#  Train Loss: 0.003591, Accuracy: 0.647176
#
# Epoch:0 Step:477/549 LSTM:
#  Train Loss: 0.003597, Accuracy: 0.648657
#
# Epoch:0 Step:478/549 LSTM:
#  Train Loss: 0.003605, Accuracy: 0.650052
#
# Epoch:0 Step:479/549 LSTM:
#  Train Loss: 0.003614, Accuracy: 0.651276
#
# Epoch:0 Step:480/549 LSTM:
#  Train Loss: 0.003620, Accuracy: 0.652771
#
# Epoch:0 Step:481/549 LSTM:
#  Train Loss: 0.003627, Accuracy: 0.654138
#
# Epoch:0 Step:482/549 LSTM:
#  Train Loss: 0.003634, Accuracy: 0.655647
#
# Epoch:0 Step:483/549 LSTM:
#  Train Loss: 0.003640, Accuracy: 0.657099
#
# Epoch:0 Step:484/549 LSTM:
#  Train Loss: 0.003647, Accuracy: 0.658495
#
# Epoch:0 Step:485/549 LSTM:
#  Train Loss: 0.003654, Accuracy: 0.660004
#
# Epoch:0 Step:486/549 LSTM:
#  Train Loss: 0.003661, Accuracy: 0.661342
#
# Epoch:0 Step:487/549 LSTM:
#  Train Loss: 0.003668, Accuracy: 0.662737
#
# Epoch:0 Step:488/549 LSTM:
#  Train Loss: 0.003676, Accuracy: 0.664161
#
# Epoch:0 Step:489/549 LSTM:
#  Train Loss: 0.003682, Accuracy: 0.665656
#
# Epoch:0 Step:490/549 LSTM:
#  Train Loss: 0.003689, Accuracy: 0.667065
#
# Epoch:0 Step:491/549 LSTM:
#  Train Loss: 0.003695, Accuracy: 0.668503
#
# Epoch:0 Step:492/549 LSTM:
#  Train Loss: 0.003702, Accuracy: 0.669870
#
# Epoch:0 Step:493/549 LSTM:
#  Train Loss: 0.003708, Accuracy: 0.671336
#
# Epoch:0 Step:494/549 LSTM:
#  Train Loss: 0.003714, Accuracy: 0.672789
#
# Epoch:0 Step:495/549 LSTM:
#  Train Loss: 0.003720, Accuracy: 0.674284
#
# Epoch:0 Step:496/549 LSTM:
#  Train Loss: 0.003726, Accuracy: 0.675764
#
# Epoch:0 Step:497/549 LSTM:
#  Train Loss: 0.003733, Accuracy: 0.677159
#
# Epoch:0 Step:498/549 LSTM:
#  Train Loss: 0.003741, Accuracy: 0.678483
#
# Epoch:0 Step:499/549 LSTM:
#  Train Loss: 0.003748, Accuracy: 0.679879
#
# Epoch:0 Step:500/549 LSTM:
#  Train Loss: 0.003754, Accuracy: 0.681331
#
# Epoch:0 Step:501/549 LSTM:
#  Train Loss: 0.003760, Accuracy: 0.682840
#
# Epoch:0 Step:502/549 LSTM:
#  Train Loss: 0.003767, Accuracy: 0.684235
#
# Epoch:0 Step:503/549 LSTM:
#  Train Loss: 0.003774, Accuracy: 0.685702
#
# Epoch:0 Step:504/549 LSTM:
#  Train Loss: 0.003781, Accuracy: 0.687125
#
# Epoch:0 Step:505/549 LSTM:
#  Train Loss: 0.003787, Accuracy: 0.688578
#
# Epoch:0 Step:506/549 LSTM:
#  Train Loss: 0.003794, Accuracy: 0.689930
#
# Epoch:0 Step:507/549 LSTM:
#  Train Loss: 0.003801, Accuracy: 0.691325
#
# Epoch:0 Step:508/549 LSTM:
#  Train Loss: 0.003808, Accuracy: 0.692692
#
# Epoch:0 Step:509/549 LSTM:
#  Train Loss: 0.003815, Accuracy: 0.694130
#
# Epoch:0 Step:510/549 LSTM:
#  Train Loss: 0.003821, Accuracy: 0.695582
#
# Epoch:0 Step:511/549 LSTM:
#  Train Loss: 0.003827, Accuracy: 0.697034
#
# Epoch:0 Step:512/549 LSTM:
#  Train Loss: 0.003834, Accuracy: 0.698358
#
# Epoch:0 Step:513/549 LSTM:
#  Train Loss: 0.003841, Accuracy: 0.699768
#
# Epoch:0 Step:514/549 LSTM:
#  Train Loss: 0.003848, Accuracy: 0.701163
#
# Epoch:0 Step:515/549 LSTM:
#  Train Loss: 0.003854, Accuracy: 0.702644
#
# Epoch:0 Step:516/549 LSTM:
#  Train Loss: 0.003861, Accuracy: 0.704068
#
# Epoch:0 Step:517/549 LSTM:
#  Train Loss: 0.003867, Accuracy: 0.705505
#
# Epoch:0 Step:518/549 LSTM:
#  Train Loss: 0.003874, Accuracy: 0.706872
#
# Epoch:0 Step:519/549 LSTM:
#  Train Loss: 0.003881, Accuracy: 0.708296
#
# Epoch:0 Step:520/549 LSTM:
#  Train Loss: 0.003888, Accuracy: 0.709663
#
# Epoch:0 Step:521/549 LSTM:
#  Train Loss: 0.003894, Accuracy: 0.711101
#
# Epoch:0 Step:522/549 LSTM:
#  Train Loss: 0.003902, Accuracy: 0.712410
#
# Epoch:0 Step:523/549 LSTM:
#  Train Loss: 0.003909, Accuracy: 0.713791
#
# Epoch:0 Step:524/549 LSTM:
#  Train Loss: 0.003916, Accuracy: 0.715158
#
# Epoch:0 Step:525/549 LSTM:
#  Train Loss: 0.003924, Accuracy: 0.716454
#
# Epoch:0 Step:526/549 LSTM:
#  Train Loss: 0.003930, Accuracy: 0.717934
#
# Epoch:0 Step:527/549 LSTM:
#  Train Loss: 0.003937, Accuracy: 0.719401
#
# Epoch:0 Step:528/549 LSTM:
#  Train Loss: 0.003943, Accuracy: 0.720839
#
# Epoch:0 Step:529/549 LSTM:
#  Train Loss: 0.003950, Accuracy: 0.722234
#
# Epoch:0 Step:530/549 LSTM:
#  Train Loss: 0.003957, Accuracy: 0.723587
#
# Epoch:0 Step:531/549 LSTM:
#  Train Loss: 0.003963, Accuracy: 0.725053
#
# Epoch:0 Step:532/549 LSTM:
#  Train Loss: 0.003970, Accuracy: 0.726505
#
# Epoch:0 Step:533/549 LSTM:
#  Train Loss: 0.003976, Accuracy: 0.728014
#
# Epoch:0 Step:534/549 LSTM:
#  Train Loss: 0.003982, Accuracy: 0.729438
#
# Epoch:0 Step:535/549 LSTM:
#  Train Loss: 0.003989, Accuracy: 0.730776
#
# Epoch:0 Step:536/549 LSTM:
#  Train Loss: 0.003996, Accuracy: 0.732157
#
# Epoch:0 Step:537/549 LSTM:
#  Train Loss: 0.004003, Accuracy: 0.733553
#
# Epoch:0 Step:538/549 LSTM:
#  Train Loss: 0.004009, Accuracy: 0.735005
#
# Epoch:0 Step:539/549 LSTM:
#  Train Loss: 0.004015, Accuracy: 0.736485
#
# Epoch:0 Step:540/549 LSTM:
#  Train Loss: 0.004021, Accuracy: 0.737966
#
# Epoch:0 Step:541/549 LSTM:
#  Train Loss: 0.004028, Accuracy: 0.739447
#
# Epoch:0 Step:542/549 LSTM:
#  Train Loss: 0.004035, Accuracy: 0.740856
#
# Epoch:0 Step:543/549 LSTM:
#  Train Loss: 0.004042, Accuracy: 0.742251
#
# Epoch:0 Step:544/549 LSTM:
#  Train Loss: 0.004048, Accuracy: 0.743675
#
# Epoch:0 Step:545/549 LSTM:
#  Train Loss: 0.004055, Accuracy: 0.745113
#
# Epoch:0 Step:546/549 LSTM:
#  Train Loss: 0.004061, Accuracy: 0.746622
#
# Epoch:0 Step:547/549 LSTM:
#  Train Loss: 0.004068, Accuracy: 0.748003
#
# Epoch:0 Step:548/549 LSTM:
#  Train Loss: 0.004075, Accuracy: 0.749427
#
# Epoch:0 Step:549/549 LSTM:
#  Train Loss: 0.004081, Accuracy: 0.750523
#
# LSTM:
#  Test Loss: 0.003739, Accuracy: 0.774040
# LSTM:
#  F1: 0.4876531918785439, recall: 0.3265556099951004, precision: 0.9624548736462094

# %%
for i in range(KFOLD):
    print('--------Fold {}----------------'.format(i))

    print('LSTM: F1:{}, prec:{}, rec:{}, acc:{}, auc:{}'.format(data_output['lstm']['F1'][i],
          data_output['lstm']['precision'][i], data_output['lstm']['recall'][i],
          data_output['lstm']['accuracy'][i], data_output['lstm']['auc'][i]))
    
    # save figures for ann, cnn, lstm
    
    plt.figure()
    
    plt.plot(data_output['lstm']['test_loss'][i], label='LSTM testing')
    plt.plot(data_output['lstm']['train_loss'][i], label='LSTM training')

    
    plt.legend()
    
    plt.xlabel('Epoch')
    plt.xticks(np.arange(0, EPOCH+1, EPOCH/10))
    plt.ylabel('Loss')
    plt.title('Loss Function')
    plt.savefig('./'+'Loss_Kfold_LSTM_w100_detection_'+str(i+1)+'.png',dpi=500)
    
    # save figures of ROC curve
    plt.figure()
    plt.plot(data_output['lstm']['fpr'][i], data_output['lstm']['tpr'][i], label='LSTM (AUC = {0:0.2f})'.format(data_output['lstm']['auc'][i]))

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.legend()
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve')
    plt.savefig('./'+'ROC__Kfold_LSTM_w100_detection_'+str(i+1)+'.png',dpi=500)
    
    
pickle_out = open('LSTM_w100_5fold_detection.pickle', 'wb')
pickle.dump(data_output, pickle_out)
pickle_out.close()

# end time
end_time = datetime.datetime.now()
print('Running time: {}'.format(end_time - start_time))
# Out:
# --------Fold 0----------------
# LSTM: F1:0.4876531918785439, prec:0.9624548736462094, rec:0.3265556099951004, acc:0.7740400129073894, auc:0.6601505497654117
# Running time: 0:10:29.854223
