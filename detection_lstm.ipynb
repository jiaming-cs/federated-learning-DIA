# %%
import loader
import torch
from torch import nn
from torch.utils.data import DataLoader
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
import sklearn.metrics
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier
import pickle
import numpy as np

import datetime

# Running time calculate: start time
start_time = datetime.datetime.now()

# Hyper Parameters
EPOCH = 1
BATCH_SIZE = 128
TIME_STEP = 100  # length of LSTM time sequence, or window size
INPUT_SIZE = 6 # num of feature for deep learning
LR = 0.001   # learning rate
KFOLD = 1
isGPU = torch.cuda.is_available()

# detection deep learning dataset path
data_path_DL = './PELS_dataset/w100_final_dataset/fault_detection/deep_learning/'
all_data_DL = loader.waveformDetectionDL(data_path_DL)

# diagnosis deep learning datasset path
#data_path_DL = '../new_clean_data/w100_final_dataset/fault_diagnosis/deep_learning/'
#all_data_DL = loader.waveformDiagnosisDL(data_path_DL)

# %%
class LSTM(nn.Module):
    def __init__(self):
        super(LSTM, self).__init__()
        
        self.lstm = nn.LSTM(
                input_size=INPUT_SIZE,
                hidden_size=32,
                num_layers=5,
                batch_first=True,
                )
        #fully connected
        #self.out = nn.Linear(32, 9)
        self.out = nn.Linear(32, 2)
    
    def forward(self, x):
        lstm_out, (h_n, h_c) = self.lstm(x, None)
        out = self.out(lstm_out[:, -1, :])
        return out

# %%
data_output = {'lstm':{'F1':[], 'precision':[], 'recall':[], 'accuracy':[], 'auc':[], 'fpr':[], 'tpr':[], 'test_loss':[], 'train_loss':[]}}

for num_of_training in range(KFOLD):
    print('------------------fold {}------------------------'.format(num_of_training + 1))
    lstm = LSTM()
    
    if isGPU:
        lstm = nn.DataParallel(lstm, device_ids=[0,1,2,3])
        lstm.cuda()

    lstm_optimizer = torch.optim.Adam(lstm.parameters(), lr=LR)
    loss_func = nn.CrossEntropyLoss()
    
    # print the structure of the network
    print(lstm)
    
    # data partition: 15% testing, 85% training
    training_data, test_data = torch.utils.data.random_split(all_data_DL, [int(all_data_DL.len * 0.85), all_data_DL.len - int(all_data_DL.len * 0.85)])
    training_Loader = DataLoader(dataset=training_data, batch_size=BATCH_SIZE, shuffle=True)
    test_Loader = DataLoader(dataset=test_data, batch_size=BATCH_SIZE)
    
    # training and testing
    lstm_test_loss_draw = []
    
    lstm_loss_draw = []
    
    for epoch in range(EPOCH):
        print('-----------------------epoch {}----------------------'.format(epoch + 1))
        
        # training-----------------------------------------
        lstm_train_loss = 0.
        
        lstm_train_acc = 0.
        
        lstm.train()
        
        for step, (batch_x, batch_y) in enumerate(training_Loader):
            batch_x = batch_x.view(-1, TIME_STEP, INPUT_SIZE)
            
            if isGPU:
                batch_x = batch_x.cuda()
                batch_y = batch_y.cuda()

            output_lstm = lstm(batch_x)
            batch_y = batch_y.type(torch.LongTensor)
            loss_lstm = loss_func(output_lstm, batch_y)
            
            lstm_train_loss += loss_lstm.item()
            
            
            
            if isGPU:
                lstm_pred = torch.max(output_lstm, 1)[1].cuda()
            else:
                lstm_pred = torch.max(output_lstm, 1)[1]
            
            lstm_train_correct = (lstm_pred == batch_y).sum()
            
            lstm_train_acc += lstm_train_correct.item()
            
            lstm_optimizer.zero_grad()
            
            loss_lstm.backward()
            
            lstm_optimizer.step()
            
            print('Epoch:{} Step:{}/{} LSTM:\n Train Loss: {:.6f}, Accuracy: {:.6f}\n'.format(epoch, step+1, len(training_Loader), lstm_train_loss / 
                (len(training_data)), lstm_train_acc / (len(training_data))))
        
        lstm_loss_draw.append(lstm_train_loss/(len(training_data)))
        
        
        # evaluation--------------------------------------------------
        lstm.eval()
        
        lstm_eval_loss = 0.
        
        lstm_eval_acc = 0.
        
        lstm_final_prediction = np.array([])
        lstm_final_test = np.array([])
        lstm_f1_score = []
        lstm_recall = []
        lstm_precision = []
        lstm_accuracy = []
      
        for step, (batch_x, batch_y) in enumerate(test_Loader):
            batch_x = batch_x.view(-1, TIME_STEP, INPUT_SIZE)
            
            if isGPU:
                batch_x = batch_x.cuda()
                batch_y = batch_y.cuda()
    
            output_lstm = lstm(batch_x)
            batch_y = batch_y.type(torch.LongTensor)
            loss_lstm = loss_func(output_lstm, batch_y)
            
            lstm_eval_loss += loss_lstm.item()
            
            lstm_pred = torch.max(output_lstm, 1)[1]
            
            lstm_eval_correct = (lstm_pred == batch_y).sum()
            
            
            if isGPU:
                lstm_pred = torch.max(output_lstm, 1)[1].cuda()
            else:
                lstm_pred = torch.max(output_lstm, 1)[1]
            
            lstm_eval_acc += lstm_eval_correct.item()
                      
            # F1 metrics
            lstm_final_prediction = np.concatenate((lstm_final_prediction, lstm_pred.cpu().numpy()), axis=0)
            lstm_final_test = np.concatenate((lstm_final_test, batch_y), axis=0)
        
        lstm_f1_score.append(sklearn.metrics.f1_score(lstm_final_test, lstm_final_prediction, average='binary').item())
        lstm_recall.append(sklearn.metrics.recall_score(lstm_final_test, lstm_final_prediction, average='binary').item())
        lstm_precision.append(sklearn.metrics.precision_score(lstm_final_test, lstm_final_prediction, average='binary').item())
        lstm_accuracy.append(lstm_eval_acc / (len(test_data)))

        
        print('LSTM:\n Test Loss: {:.6f}, Accuracy: {:.6f}'.format(lstm_eval_loss / (len(test_data)), lstm_eval_acc / (len(test_data))))
        
        lstm_test_loss_draw.append(lstm_eval_loss/(len(test_data)))
        
        print('LSTM:\n F1: {}, recall: {}, precision: {}'.format(lstm_f1_score[-1], lstm_recall[-1], lstm_precision[-1]))
        
    # ROC curve and AUC
    #lstm_test_y = label_binarize(lstm_final_test, classes=[0, 1, 2, 3, 4, 5, 6, 7, 8])
    #lstm_pred_y = label_binarize(lstm_final_prediction, classes=[0, 1, 2, 3, 4, 5, 6, 7, 8])
    lstm_test_y = label_binarize(lstm_final_test, classes=[0, 1])
    lstm_pred_y = label_binarize(lstm_final_prediction, classes=[0, 1])
    
    lstm_fpr, lstm_tpr, _ = roc_curve(lstm_test_y.ravel(), lstm_pred_y.ravel())
    lstm_roc_auc = auc(lstm_fpr, lstm_tpr)
    
    
    data_output['lstm']['F1'].append(lstm_f1_score[-1])
    data_output['lstm']['precision'].append(lstm_precision[-1])
    data_output['lstm']['recall'].append(lstm_recall[-1])
    data_output['lstm']['accuracy'].append(lstm_accuracy[-1])
    data_output['lstm']['auc'].append(lstm_roc_auc.item())
    data_output['lstm']['fpr'].append(list(lstm_fpr))
    data_output['lstm']['tpr'].append(list(lstm_tpr))
    data_output['lstm']['test_loss'].append(lstm_test_loss_draw)
    data_output['lstm']['train_loss'].append(lstm_loss_draw)
# Out:
# 6/549 LSTM:
#  Train Loss: 0.002120, Accuracy: 0.355771
#
# Epoch:0 Step:267/549 LSTM:
#  Train Loss: 0.002127, Accuracy: 0.357138
#
# Epoch:0 Step:268/549 LSTM:
#  Train Loss: 0.002135, Accuracy: 0.358376
#
# Epoch:0 Step:269/549 LSTM:
#  Train Loss: 0.002143, Accuracy: 0.359729
#
# Epoch:0 Step:270/549 LSTM:
#  Train Loss: 0.002150, Accuracy: 0.361224
#
# Epoch:0 Step:271/549 LSTM:
#  Train Loss: 0.002157, Accuracy: 0.362576
#
# Epoch:0 Step:272/549 LSTM:
#  Train Loss: 0.002164, Accuracy: 0.364043
#
# Epoch:0 Step:273/549 LSTM:
#  Train Loss: 0.002171, Accuracy: 0.365495
#
# Epoch:0 Step:274/549 LSTM:
#  Train Loss: 0.002179, Accuracy: 0.366890
#
# Epoch:0 Step:275/549 LSTM:
#  Train Loss: 0.002186, Accuracy: 0.368228
#
# Epoch:0 Step:276/549 LSTM:
#  Train Loss: 0.002193, Accuracy: 0.369624
#
# Epoch:0 Step:277/549 LSTM:
#  Train Loss: 0.002200, Accuracy: 0.371019
#
# Epoch:0 Step:278/549 LSTM:
#  Train Loss: 0.002207, Accuracy: 0.372471
#
# Epoch:0 Step:279/549 LSTM:
#  Train Loss: 0.002214, Accuracy: 0.373923
#
# Epoch:0 Step:280/549 LSTM:
#  Train Loss: 0.002221, Accuracy: 0.375418
#
# Epoch:0 Step:281/549 LSTM:
#  Train Loss: 0.002228, Accuracy: 0.376885
#
# Epoch:0 Step:282/549 LSTM:
#  Train Loss: 0.002235, Accuracy: 0.378337
#
# Epoch:0 Step:283/549 LSTM:
#  Train Loss: 0.002242, Accuracy: 0.379761
#
# Epoch:0 Step:284/549 LSTM:
#  Train Loss: 0.002249, Accuracy: 0.381170
#
# Epoch:0 Step:285/549 LSTM:
#  Train Loss: 0.002257, Accuracy: 0.382508
#
# Epoch:0 Step:286/549 LSTM:
#  Train Loss: 0.002266, Accuracy: 0.383775
#
# Epoch:0 Step:287/549 LSTM:
#  Train Loss: 0.002273, Accuracy: 0.385185
#
# Epoch:0 Step:288/549 LSTM:
#  Train Loss: 0.002283, Accuracy: 0.386423
#
# Epoch:0 Step:289/549 LSTM:
#  Train Loss: 0.002289, Accuracy: 0.387876
#
# Epoch:0 Step:290/549 LSTM:
#  Train Loss: 0.002297, Accuracy: 0.389285
#
# Epoch:0 Step:291/549 LSTM:
#  Train Loss: 0.002305, Accuracy: 0.390623
#
# Epoch:0 Step:292/549 LSTM:
#  Train Loss: 0.002313, Accuracy: 0.391848
#
# Epoch:0 Step:293/549 LSTM:
#  Train Loss: 0.002320, Accuracy: 0.393357
#
# Epoch:0 Step:294/549 LSTM:
#  Train Loss: 0.002328, Accuracy: 0.394653
#
# Epoch:0 Step:295/549 LSTM:
#  Train Loss: 0.002335, Accuracy: 0.396076
#
# Epoch:0 Step:296/549 LSTM:
#  Train Loss: 0.002343, Accuracy: 0.397386
#
# Epoch:0 Step:297/549 LSTM:
#  Train Loss: 0.002350, Accuracy: 0.398710
#
# Epoch:0 Step:298/549 LSTM:
#  Train Loss: 0.002358, Accuracy: 0.400105
#
# Epoch:0 Step:299/549 LSTM:
#  Train Loss: 0.002365, Accuracy: 0.401543
#
# Epoch:0 Step:300/549 LSTM:
#  Train Loss: 0.002372, Accuracy: 0.403052
#
# Epoch:0 Step:301/549 LSTM:
#  Train Loss: 0.002379, Accuracy: 0.404505
#
# Epoch:0 Step:302/549 LSTM:
#  Train Loss: 0.002386, Accuracy: 0.406000
#
# Epoch:0 Step:303/549 LSTM:
#  Train Loss: 0.002393, Accuracy: 0.407267
#
# Epoch:0 Step:304/549 LSTM:
#  Train Loss: 0.002401, Accuracy: 0.408719
#
# Epoch:0 Step:305/549 LSTM:
#  Train Loss: 0.002409, Accuracy: 0.410086
#
# Epoch:0 Step:306/549 LSTM:
#  Train Loss: 0.002417, Accuracy: 0.411524
#
# Epoch:0 Step:307/549 LSTM:
#  Train Loss: 0.002424, Accuracy: 0.412961
#
# Epoch:0 Step:308/549 LSTM:
#  Train Loss: 0.002431, Accuracy: 0.414456
#
# Epoch:0 Step:309/549 LSTM:
#  Train Loss: 0.002438, Accuracy: 0.415823
#
# Epoch:0 Step:310/549 LSTM:
#  Train Loss: 0.002446, Accuracy: 0.417133
#
# Epoch:0 Step:311/549 LSTM:
#  Train Loss: 0.002453, Accuracy: 0.418571
#
# Epoch:0 Step:312/549 LSTM:
#  Train Loss: 0.002461, Accuracy: 0.419895
#
# Epoch:0 Step:313/549 LSTM:
#  Train Loss: 0.002469, Accuracy: 0.421219
#
# Epoch:0 Step:314/549 LSTM:
#  Train Loss: 0.002478, Accuracy: 0.422515
#
# Epoch:0 Step:315/549 LSTM:
#  Train Loss: 0.002485, Accuracy: 0.423853
#
# Epoch:0 Step:316/549 LSTM:
#  Train Loss: 0.002494, Accuracy: 0.425120
#
# Epoch:0 Step:317/549 LSTM:
#  Train Loss: 0.002502, Accuracy: 0.426430
#
# Epoch:0 Step:318/549 LSTM:
#  Train Loss: 0.002511, Accuracy: 0.427683
#
# Epoch:0 Step:319/549 LSTM:
#  Train Loss: 0.002518, Accuracy: 0.429021
#
# Epoch:0 Step:320/549 LSTM:
#  Train Loss: 0.002526, Accuracy: 0.430402
#
# Epoch:0 Step:321/549 LSTM:
#  Train Loss: 0.002532, Accuracy: 0.431954
#
# Epoch:0 Step:322/549 LSTM:
#  Train Loss: 0.002539, Accuracy: 0.433377
#
# Epoch:0 Step:323/549 LSTM:
#  Train Loss: 0.002546, Accuracy: 0.434858
#
# Epoch:0 Step:324/549 LSTM:
#  Train Loss: 0.002554, Accuracy: 0.436239
#
# Epoch:0 Step:325/549 LSTM:
#  Train Loss: 0.002562, Accuracy: 0.437506
#
# Epoch:0 Step:326/549 LSTM:
#  Train Loss: 0.002569, Accuracy: 0.438873
#
# Epoch:0 Step:327/549 LSTM:
#  Train Loss: 0.002577, Accuracy: 0.440211
#
# Epoch:0 Step:328/549 LSTM:
#  Train Loss: 0.002584, Accuracy: 0.441706
#
# Epoch:0 Step:329/549 LSTM:
#  Train Loss: 0.002590, Accuracy: 0.443230
#
# Epoch:0 Step:330/549 LSTM:
#  Train Loss: 0.002598, Accuracy: 0.444611
#
# Epoch:0 Step:331/549 LSTM:
#  Train Loss: 0.002605, Accuracy: 0.445977
#
# Epoch:0 Step:332/549 LSTM:
#  Train Loss: 0.002612, Accuracy: 0.447373
#
# Epoch:0 Step:333/549 LSTM:
#  Train Loss: 0.002618, Accuracy: 0.448867
#
# Epoch:0 Step:334/549 LSTM:
#  Train Loss: 0.002626, Accuracy: 0.450248
#
# Epoch:0 Step:335/549 LSTM:
#  Train Loss: 0.002633, Accuracy: 0.451672
#
# Epoch:0 Step:336/549 LSTM:
#  Train Loss: 0.002639, Accuracy: 0.453153
#
# Epoch:0 Step:337/549 LSTM:
#  Train Loss: 0.002646, Accuracy: 0.454605
#
# Epoch:0 Step:338/549 LSTM:
#  Train Loss: 0.002654, Accuracy: 0.455958
#
# Epoch:0 Step:339/549 LSTM:
#  Train Loss: 0.002661, Accuracy: 0.457410
#
# Epoch:0 Step:340/549 LSTM:
#  Train Loss: 0.002667, Accuracy: 0.458876
#
# Epoch:0 Step:341/549 LSTM:
#  Train Loss: 0.002675, Accuracy: 0.460243
#
# Epoch:0 Step:342/549 LSTM:
#  Train Loss: 0.002683, Accuracy: 0.461652
#
# Epoch:0 Step:343/549 LSTM:
#  Train Loss: 0.002691, Accuracy: 0.462991
#
# Epoch:0 Step:344/549 LSTM:
#  Train Loss: 0.002699, Accuracy: 0.464286
#
# Epoch:0 Step:345/549 LSTM:
#  Train Loss: 0.002708, Accuracy: 0.465539
#
# Epoch:0 Step:346/549 LSTM:
#  Train Loss: 0.002717, Accuracy: 0.466778
#
# Epoch:0 Step:347/549 LSTM:
#  Train Loss: 0.002726, Accuracy: 0.468031
#
# Epoch:0 Step:348/549 LSTM:
#  Train Loss: 0.002733, Accuracy: 0.469397
#
# Epoch:0 Step:349/549 LSTM:
#  Train Loss: 0.002741, Accuracy: 0.470807
#
# Epoch:0 Step:350/549 LSTM:
#  Train Loss: 0.002749, Accuracy: 0.472074
#
# Epoch:0 Step:351/549 LSTM:
#  Train Loss: 0.002757, Accuracy: 0.473369
#
# Epoch:0 Step:352/549 LSTM:
#  Train Loss: 0.002765, Accuracy: 0.474722
#
# Epoch:0 Step:353/549 LSTM:
#  Train Loss: 0.002773, Accuracy: 0.476060
#
# Epoch:0 Step:354/549 LSTM:
#  Train Loss: 0.002781, Accuracy: 0.477413
#
# Epoch:0 Step:355/549 LSTM:
#  Train Loss: 0.002788, Accuracy: 0.478780
#
# Epoch:0 Step:356/549 LSTM:
#  Train Loss: 0.002796, Accuracy: 0.480161
#
# Epoch:0 Step:357/549 LSTM:
#  Train Loss: 0.002803, Accuracy: 0.481556
#
# Epoch:0 Step:358/549 LSTM:
#  Train Loss: 0.002811, Accuracy: 0.482894
#
# Epoch:0 Step:359/549 LSTM:
#  Train Loss: 0.002818, Accuracy: 0.484403
#
# Epoch:0 Step:360/549 LSTM:
#  Train Loss: 0.002826, Accuracy: 0.485756
#
# Epoch:0 Step:361/549 LSTM:
#  Train Loss: 0.002834, Accuracy: 0.487108
#
# Epoch:0 Step:362/549 LSTM:
#  Train Loss: 0.002841, Accuracy: 0.488532
#
# Epoch:0 Step:363/549 LSTM:
#  Train Loss: 0.002849, Accuracy: 0.489899
#
# Epoch:0 Step:364/549 LSTM:
#  Train Loss: 0.002856, Accuracy: 0.491351
#
# Epoch:0 Step:365/549 LSTM:
#  Train Loss: 0.002863, Accuracy: 0.492760
#
# Epoch:0 Step:366/549 LSTM:
#  Train Loss: 0.002872, Accuracy: 0.494084
#
# Epoch:0 Step:367/549 LSTM:
#  Train Loss: 0.002879, Accuracy: 0.495465
#
# Epoch:0 Step:368/549 LSTM:
#  Train Loss: 0.002887, Accuracy: 0.496790
#
# Epoch:0 Step:369/549 LSTM:
#  Train Loss: 0.002895, Accuracy: 0.498085
#
# Epoch:0 Step:370/549 LSTM:
#  Train Loss: 0.002903, Accuracy: 0.499452
#
# Epoch:0 Step:371/549 LSTM:
#  Train Loss: 0.002910, Accuracy: 0.500876
#
# Epoch:0 Step:372/549 LSTM:
#  Train Loss: 0.002918, Accuracy: 0.502228
#
# Epoch:0 Step:373/549 LSTM:
#  Train Loss: 0.002925, Accuracy: 0.503609
#
# Epoch:0 Step:374/549 LSTM:
#  Train Loss: 0.002931, Accuracy: 0.505118
#
# Epoch:0 Step:375/549 LSTM:
#  Train Loss: 0.002939, Accuracy: 0.506471
#
# Epoch:0 Step:376/549 LSTM:
#  Train Loss: 0.002946, Accuracy: 0.507894
#
# Epoch:0 Step:377/549 LSTM:
#  Train Loss: 0.002954, Accuracy: 0.509261
#
# Epoch:0 Step:378/549 LSTM:
#  Train Loss: 0.002960, Accuracy: 0.510770
#
# Epoch:0 Step:379/549 LSTM:
#  Train Loss: 0.002967, Accuracy: 0.512237
#
# Epoch:0 Step:380/549 LSTM:
#  Train Loss: 0.002973, Accuracy: 0.513746
#
# Epoch:0 Step:381/549 LSTM:
#  Train Loss: 0.002982, Accuracy: 0.515042
#
# Epoch:0 Step:382/549 LSTM:
#  Train Loss: 0.002988, Accuracy: 0.516536
#
# Epoch:0 Step:383/549 LSTM:
#  Train Loss: 0.002995, Accuracy: 0.517903
#
# Epoch:0 Step:384/549 LSTM:
#  Train Loss: 0.003003, Accuracy: 0.519298
#
# Epoch:0 Step:385/549 LSTM:
#  Train Loss: 0.003010, Accuracy: 0.520679
#
# Epoch:0 Step:386/549 LSTM:
#  Train Loss: 0.003019, Accuracy: 0.521918
#
# Epoch:0 Step:387/549 LSTM:
#  Train Loss: 0.003026, Accuracy: 0.523342
#
# Epoch:0 Step:388/549 LSTM:
#  Train Loss: 0.003032, Accuracy: 0.524822
#
# Epoch:0 Step:389/549 LSTM:
#  Train Loss: 0.003040, Accuracy: 0.526161
#
# Epoch:0 Step:390/549 LSTM:
#  Train Loss: 0.003047, Accuracy: 0.527599
#
# Epoch:0 Step:391/549 LSTM:
#  Train Loss: 0.003056, Accuracy: 0.528880
#
# Epoch:0 Step:392/549 LSTM:
#  Train Loss: 0.003063, Accuracy: 0.530289
#
# Epoch:0 Step:393/549 LSTM:
#  Train Loss: 0.003069, Accuracy: 0.531784
#
# Epoch:0 Step:394/549 LSTM:
#  Train Loss: 0.003077, Accuracy: 0.533208
#
# Epoch:0 Step:395/549 LSTM:
#  Train Loss: 0.003084, Accuracy: 0.534646
#
# Epoch:0 Step:396/549 LSTM:
#  Train Loss: 0.003090, Accuracy: 0.536155
#
# Epoch:0 Step:397/549 LSTM:
#  Train Loss: 0.003098, Accuracy: 0.537493
#
# Epoch:0 Step:398/549 LSTM:
#  Train Loss: 0.003104, Accuracy: 0.538960
#
# Epoch:0 Step:399/549 LSTM:
#  Train Loss: 0.003112, Accuracy: 0.540298
#
# Epoch:0 Step:400/549 LSTM:
#  Train Loss: 0.003119, Accuracy: 0.541765
#
# Epoch:0 Step:401/549 LSTM:
#  Train Loss: 0.003125, Accuracy: 0.543188
#
# Epoch:0 Step:402/549 LSTM:
#  Train Loss: 0.003132, Accuracy: 0.544640
#
# Epoch:0 Step:403/549 LSTM:
#  Train Loss: 0.003139, Accuracy: 0.546021
#
# Epoch:0 Step:404/549 LSTM:
#  Train Loss: 0.003146, Accuracy: 0.547488
#
# Epoch:0 Step:405/549 LSTM:
#  Train Loss: 0.003154, Accuracy: 0.548812
#
# Epoch:0 Step:406/549 LSTM:
#  Train Loss: 0.003163, Accuracy: 0.550107
#
# Epoch:0 Step:407/549 LSTM:
#  Train Loss: 0.003171, Accuracy: 0.551503
#
# Epoch:0 Step:408/549 LSTM:
#  Train Loss: 0.003177, Accuracy: 0.552983
#
# Epoch:0 Step:409/549 LSTM:
#  Train Loss: 0.003184, Accuracy: 0.554393
#
# Epoch:0 Step:410/549 LSTM:
#  Train Loss: 0.003192, Accuracy: 0.555788
#
# Epoch:0 Step:411/549 LSTM:
#  Train Loss: 0.003200, Accuracy: 0.557069
#
# Epoch:0 Step:412/549 LSTM:
#  Train Loss: 0.003207, Accuracy: 0.558479
#
# Epoch:0 Step:413/549 LSTM:
#  Train Loss: 0.003215, Accuracy: 0.559732
#
# Epoch:0 Step:414/549 LSTM:
#  Train Loss: 0.003222, Accuracy: 0.561198
#
# Epoch:0 Step:415/549 LSTM:
#  Train Loss: 0.003229, Accuracy: 0.562608
#
# Epoch:0 Step:416/549 LSTM:
#  Train Loss: 0.003236, Accuracy: 0.564003
#
# Epoch:0 Step:417/549 LSTM:
#  Train Loss: 0.003244, Accuracy: 0.565284
#
# Epoch:0 Step:418/549 LSTM:
#  Train Loss: 0.003251, Accuracy: 0.566566
#
# Epoch:0 Step:419/549 LSTM:
#  Train Loss: 0.003258, Accuracy: 0.568032
#
# Epoch:0 Step:420/549 LSTM:
#  Train Loss: 0.003265, Accuracy: 0.569356
#
# Epoch:0 Step:421/549 LSTM:
#  Train Loss: 0.003272, Accuracy: 0.570709
#
# Epoch:0 Step:422/549 LSTM:
#  Train Loss: 0.003278, Accuracy: 0.572203
#
# Epoch:0 Step:423/549 LSTM:
#  Train Loss: 0.003285, Accuracy: 0.573641
#
# Epoch:0 Step:424/549 LSTM:
#  Train Loss: 0.003292, Accuracy: 0.574994
#
# Epoch:0 Step:425/549 LSTM:
#  Train Loss: 0.003300, Accuracy: 0.576403
#
# Epoch:0 Step:426/549 LSTM:
#  Train Loss: 0.003307, Accuracy: 0.577870
#
# Epoch:0 Step:427/549 LSTM:
#  Train Loss: 0.003313, Accuracy: 0.579365
#
# Epoch:0 Step:428/549 LSTM:
#  Train Loss: 0.003320, Accuracy: 0.580774
#
# Epoch:0 Step:429/549 LSTM:
#  Train Loss: 0.003326, Accuracy: 0.582255
#
# Epoch:0 Step:430/549 LSTM:
#  Train Loss: 0.003334, Accuracy: 0.583636
#
# Epoch:0 Step:431/549 LSTM:
#  Train Loss: 0.003341, Accuracy: 0.585060
#
# Epoch:0 Step:432/549 LSTM:
#  Train Loss: 0.003348, Accuracy: 0.586483
#
# Epoch:0 Step:433/549 LSTM:
#  Train Loss: 0.003354, Accuracy: 0.587964
#
# Epoch:0 Step:434/549 LSTM:
#  Train Loss: 0.003361, Accuracy: 0.589373
#
# Epoch:0 Step:435/549 LSTM:
#  Train Loss: 0.003367, Accuracy: 0.590883
#
# Epoch:0 Step:436/549 LSTM:
#  Train Loss: 0.003373, Accuracy: 0.592434
#
# Epoch:0 Step:437/549 LSTM:
#  Train Loss: 0.003380, Accuracy: 0.593815
#
# Epoch:0 Step:438/549 LSTM:
#  Train Loss: 0.003386, Accuracy: 0.595296
#
# Epoch:0 Step:439/549 LSTM:
#  Train Loss: 0.003394, Accuracy: 0.596606
#
# Epoch:0 Step:440/549 LSTM:
#  Train Loss: 0.003401, Accuracy: 0.598044
#
# Epoch:0 Step:441/549 LSTM:
#  Train Loss: 0.003409, Accuracy: 0.599425
#
# Epoch:0 Step:442/549 LSTM:
#  Train Loss: 0.003415, Accuracy: 0.600863
#
# Epoch:0 Step:443/549 LSTM:
#  Train Loss: 0.003423, Accuracy: 0.602272
#
# Epoch:0 Step:444/549 LSTM:
#  Train Loss: 0.003429, Accuracy: 0.603767
#
# Epoch:0 Step:445/549 LSTM:
#  Train Loss: 0.003436, Accuracy: 0.605162
#
# Epoch:0 Step:446/549 LSTM:
#  Train Loss: 0.003443, Accuracy: 0.606643
#
# Epoch:0 Step:447/549 LSTM:
#  Train Loss: 0.003449, Accuracy: 0.608138
#
# Epoch:0 Step:448/549 LSTM:
#  Train Loss: 0.003456, Accuracy: 0.609647
#
# Epoch:0 Step:449/549 LSTM:
#  Train Loss: 0.003462, Accuracy: 0.611057
#
# Epoch:0 Step:450/549 LSTM:
#  Train Loss: 0.003469, Accuracy: 0.612466
#
# Epoch:0 Step:451/549 LSTM:
#  Train Loss: 0.003475, Accuracy: 0.613947
#
# Epoch:0 Step:452/549 LSTM:
#  Train Loss: 0.003482, Accuracy: 0.615356
#
# Epoch:0 Step:453/549 LSTM:
#  Train Loss: 0.003488, Accuracy: 0.616851
#
# Epoch:0 Step:454/549 LSTM:
#  Train Loss: 0.003495, Accuracy: 0.618303
#
# Epoch:0 Step:455/549 LSTM:
#  Train Loss: 0.003502, Accuracy: 0.619741
#
# Epoch:0 Step:456/549 LSTM:
#  Train Loss: 0.003507, Accuracy: 0.621307
#
# Epoch:0 Step:457/549 LSTM:
#  Train Loss: 0.003515, Accuracy: 0.622631
#
# Epoch:0 Step:458/549 LSTM:
#  Train Loss: 0.003522, Accuracy: 0.623941
#
# Epoch:0 Step:459/549 LSTM:
#  Train Loss: 0.003529, Accuracy: 0.625294
#
# Epoch:0 Step:460/549 LSTM:
#  Train Loss: 0.003536, Accuracy: 0.626703
#
# Epoch:0 Step:461/549 LSTM:
#  Train Loss: 0.003543, Accuracy: 0.628127
#
# Epoch:0 Step:462/549 LSTM:
#  Train Loss: 0.003550, Accuracy: 0.629508
#
# Epoch:0 Step:463/549 LSTM:
#  Train Loss: 0.003557, Accuracy: 0.630932
#
# Epoch:0 Step:464/549 LSTM:
#  Train Loss: 0.003563, Accuracy: 0.632426
#
# Epoch:0 Step:465/549 LSTM:
#  Train Loss: 0.003570, Accuracy: 0.633879
#
# Epoch:0 Step:466/549 LSTM:
#  Train Loss: 0.003576, Accuracy: 0.635359
#
# Epoch:0 Step:467/549 LSTM:
#  Train Loss: 0.003584, Accuracy: 0.636712
#
# Epoch:0 Step:468/549 LSTM:
#  Train Loss: 0.003591, Accuracy: 0.638022
#
# Epoch:0 Step:469/549 LSTM:
#  Train Loss: 0.003599, Accuracy: 0.639360
#
# Epoch:0 Step:470/549 LSTM:
#  Train Loss: 0.003606, Accuracy: 0.640769
#
# Epoch:0 Step:471/549 LSTM:
#  Train Loss: 0.003614, Accuracy: 0.642150
#
# Epoch:0 Step:472/549 LSTM:
#  Train Loss: 0.003620, Accuracy: 0.643631
#
# Epoch:0 Step:473/549 LSTM:
#  Train Loss: 0.003627, Accuracy: 0.645083
#
# Epoch:0 Step:474/549 LSTM:
#  Train Loss: 0.003633, Accuracy: 0.646550
#
# Epoch:0 Step:475/549 LSTM:
#  Train Loss: 0.003640, Accuracy: 0.647945
#
# Epoch:0 Step:476/549 LSTM:
#  Train Loss: 0.003647, Accuracy: 0.649397
#
# Epoch:0 Step:477/549 LSTM:
#  Train Loss: 0.003654, Accuracy: 0.650821
#
# Epoch:0 Step:478/549 LSTM:
#  Train Loss: 0.003661, Accuracy: 0.652287
#
# Epoch:0 Step:479/549 LSTM:
#  Train Loss: 0.003668, Accuracy: 0.653711
#
# Epoch:0 Step:480/549 LSTM:
#  Train Loss: 0.003674, Accuracy: 0.655177
#
# Epoch:0 Step:481/549 LSTM:
#  Train Loss: 0.003680, Accuracy: 0.656630
#
# Epoch:0 Step:482/549 LSTM:
#  Train Loss: 0.003687, Accuracy: 0.658053
#
# Epoch:0 Step:483/549 LSTM:
#  Train Loss: 0.003694, Accuracy: 0.659577
#
# Epoch:0 Step:484/549 LSTM:
#  Train Loss: 0.003702, Accuracy: 0.660886
#
# Epoch:0 Step:485/549 LSTM:
#  Train Loss: 0.003708, Accuracy: 0.662367
#
# Epoch:0 Step:486/549 LSTM:
#  Train Loss: 0.003715, Accuracy: 0.663848
#
# Epoch:0 Step:487/549 LSTM:
#  Train Loss: 0.003722, Accuracy: 0.665343
#
# Epoch:0 Step:488/549 LSTM:
#  Train Loss: 0.003729, Accuracy: 0.666752
#
# Epoch:0 Step:489/549 LSTM:
#  Train Loss: 0.003737, Accuracy: 0.668105
#
# Epoch:0 Step:490/549 LSTM:
#  Train Loss: 0.003743, Accuracy: 0.669585
#
# Epoch:0 Step:491/549 LSTM:
#  Train Loss: 0.003749, Accuracy: 0.671109
#
# Epoch:0 Step:492/549 LSTM:
#  Train Loss: 0.003755, Accuracy: 0.672575
#
# Epoch:0 Step:493/549 LSTM:
#  Train Loss: 0.003761, Accuracy: 0.674056
#
# Epoch:0 Step:494/549 LSTM:
#  Train Loss: 0.003768, Accuracy: 0.675451
#
# Epoch:0 Step:495/549 LSTM:
#  Train Loss: 0.003776, Accuracy: 0.676860
#
# Epoch:0 Step:496/549 LSTM:
#  Train Loss: 0.003783, Accuracy: 0.678199
#
# Epoch:0 Step:497/549 LSTM:
#  Train Loss: 0.003789, Accuracy: 0.679694
#
# Epoch:0 Step:498/549 LSTM:
#  Train Loss: 0.003797, Accuracy: 0.681117
#
# Epoch:0 Step:499/549 LSTM:
#  Train Loss: 0.003804, Accuracy: 0.682456
#
# Epoch:0 Step:500/549 LSTM:
#  Train Loss: 0.003812, Accuracy: 0.683808
#
# Epoch:0 Step:501/549 LSTM:
#  Train Loss: 0.003822, Accuracy: 0.685047
#
# Epoch:0 Step:502/549 LSTM:
#  Train Loss: 0.003829, Accuracy: 0.686399
#
# Epoch:0 Step:503/549 LSTM:
#  Train Loss: 0.003836, Accuracy: 0.687823
#
# Epoch:0 Step:504/549 LSTM:
#  Train Loss: 0.003843, Accuracy: 0.689275
#
# Epoch:0 Step:505/549 LSTM:
#  Train Loss: 0.003850, Accuracy: 0.690813
#
# Epoch:0 Step:506/549 LSTM:
#  Train Loss: 0.003856, Accuracy: 0.692308
#
# Epoch:0 Step:507/549 LSTM:
#  Train Loss: 0.003863, Accuracy: 0.693788
#
# Epoch:0 Step:508/549 LSTM:
#  Train Loss: 0.003871, Accuracy: 0.695112
#
# Epoch:0 Step:509/549 LSTM:
#  Train Loss: 0.003878, Accuracy: 0.696550
#
# Epoch:0 Step:510/549 LSTM:
#  Train Loss: 0.003884, Accuracy: 0.698003
#
# Epoch:0 Step:511/549 LSTM:
#  Train Loss: 0.003891, Accuracy: 0.699426
#
# Epoch:0 Step:512/549 LSTM:
#  Train Loss: 0.003899, Accuracy: 0.700750
#
# Epoch:0 Step:513/549 LSTM:
#  Train Loss: 0.003907, Accuracy: 0.702060
#
# Epoch:0 Step:514/549 LSTM:
#  Train Loss: 0.003912, Accuracy: 0.703626
#
# Epoch:0 Step:515/549 LSTM:
#  Train Loss: 0.003919, Accuracy: 0.705078
#
# Epoch:0 Step:516/549 LSTM:
#  Train Loss: 0.003926, Accuracy: 0.706417
#
# Epoch:0 Step:517/549 LSTM:
#  Train Loss: 0.003934, Accuracy: 0.707741
#
# Epoch:0 Step:518/549 LSTM:
#  Train Loss: 0.003941, Accuracy: 0.709236
#
# Epoch:0 Step:519/549 LSTM:
#  Train Loss: 0.003948, Accuracy: 0.710645
#
# Epoch:0 Step:520/549 LSTM:
#  Train Loss: 0.003955, Accuracy: 0.712069
#
# Epoch:0 Step:521/549 LSTM:
#  Train Loss: 0.003962, Accuracy: 0.713549
#
# Epoch:0 Step:522/549 LSTM:
#  Train Loss: 0.003969, Accuracy: 0.714945
#
# Epoch:0 Step:523/549 LSTM:
#  Train Loss: 0.003976, Accuracy: 0.716297
#
# Epoch:0 Step:524/549 LSTM:
#  Train Loss: 0.003983, Accuracy: 0.717692
#
# Epoch:0 Step:525/549 LSTM:
#  Train Loss: 0.003990, Accuracy: 0.719102
#
# Epoch:0 Step:526/549 LSTM:
#  Train Loss: 0.003997, Accuracy: 0.720511
#
# Epoch:0 Step:527/549 LSTM:
#  Train Loss: 0.004003, Accuracy: 0.722049
#
# Epoch:0 Step:528/549 LSTM:
#  Train Loss: 0.004010, Accuracy: 0.723558
#
# Epoch:0 Step:529/549 LSTM:
#  Train Loss: 0.004017, Accuracy: 0.724968
#
# Epoch:0 Step:530/549 LSTM:
#  Train Loss: 0.004025, Accuracy: 0.726306
#
# Epoch:0 Step:531/549 LSTM:
#  Train Loss: 0.004031, Accuracy: 0.727801
#
# Epoch:0 Step:532/549 LSTM:
#  Train Loss: 0.004038, Accuracy: 0.729225
#
# Epoch:0 Step:533/549 LSTM:
#  Train Loss: 0.004046, Accuracy: 0.730492
#
# Epoch:0 Step:534/549 LSTM:
#  Train Loss: 0.004053, Accuracy: 0.731901
#
# Epoch:0 Step:535/549 LSTM:
#  Train Loss: 0.004061, Accuracy: 0.733239
#
# Epoch:0 Step:536/549 LSTM:
#  Train Loss: 0.004067, Accuracy: 0.734734
#
# Epoch:0 Step:537/549 LSTM:
#  Train Loss: 0.004074, Accuracy: 0.736130
#
# Epoch:0 Step:538/549 LSTM:
#  Train Loss: 0.004080, Accuracy: 0.737596
#
# Epoch:0 Step:539/549 LSTM:
#  Train Loss: 0.004087, Accuracy: 0.739005
#
# Epoch:0 Step:540/549 LSTM:
#  Train Loss: 0.004095, Accuracy: 0.740358
#
# Epoch:0 Step:541/549 LSTM:
#  Train Loss: 0.004102, Accuracy: 0.741725
#
# Epoch:0 Step:542/549 LSTM:
#  Train Loss: 0.004108, Accuracy: 0.743248
#
# Epoch:0 Step:543/549 LSTM:
#  Train Loss: 0.004115, Accuracy: 0.744586
#
# Epoch:0 Step:544/549 LSTM:
#  Train Loss: 0.004122, Accuracy: 0.746081
#
# Epoch:0 Step:545/549 LSTM:
#  Train Loss: 0.004129, Accuracy: 0.747405
#
# Epoch:0 Step:546/549 LSTM:
#  Train Loss: 0.004137, Accuracy: 0.748715
#
# Epoch:0 Step:547/549 LSTM:
#  Train Loss: 0.004146, Accuracy: 0.749939
#
# Epoch:0 Step:548/549 LSTM:
#  Train Loss: 0.004153, Accuracy: 0.751406
#
# Epoch:0 Step:549/549 LSTM:
#  Train Loss: 0.004161, Accuracy: 0.752417
#
# LSTM:
#  Test Loss: 0.003948, Accuracy: 0.762504
# LSTM:
#  F1: 0.4608058608058607, recall: 0.3003103365958463, precision: 0.989771833202203

# %%
for i in range(KFOLD):
    print('--------Fold {}----------------'.format(i))

    print('LSTM: F1:{}, prec:{}, rec:{}, acc:{}, auc:{}'.format(data_output['lstm']['F1'][i],
          data_output['lstm']['precision'][i], data_output['lstm']['recall'][i],
          data_output['lstm']['accuracy'][i], data_output['lstm']['auc'][i]))
    
    # save figures for ann, cnn, lstm
    
    plt.figure()
    
    plt.plot(data_output['lstm']['test_loss'][i], label='LSTM testing')
    plt.plot(data_output['lstm']['train_loss'][i], label='LSTM training')

    
    plt.legend()
    
    plt.xlabel('Epoch')
    plt.xticks(np.arange(0, EPOCH+1, EPOCH/10))
    plt.ylabel('Loss')
    plt.title('Loss Function')
    plt.savefig('./'+'Loss_Kfold_LSTM_w100_detection_'+str(i+1)+'.png',dpi=500)
    
    # save figures of ROC curve
    plt.figure()
    plt.plot(data_output['lstm']['fpr'][i], data_output['lstm']['tpr'][i], label='LSTM (AUC = {0:0.2f})'.format(data_output['lstm']['auc'][i]))

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.legend()
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve')
    plt.savefig('./'+'ROC__Kfold_LSTM_w100_detection_'+str(i+1)+'.png',dpi=500)
    
    
pickle_out = open('LSTM_w100_5fold_detection.pickle', 'wb')
pickle.dump(data_output, pickle_out)
pickle_out.close()

# end time
end_time = datetime.datetime.now()
print('Running time: {}'.format(end_time - start_time))
# Out:
# --------Fold 0----------------
# LSTM: F1:0.4876531918785439, prec:0.9624548736462094, rec:0.3265556099951004, acc:0.7740400129073894, auc:0.6601505497654117
# Running time: 0:10:29.854223
